# %%
def get_grade_point(total_marks):
    if total_marks >= 90:
        return 10
    elif total_marks >= 80:
        return 9
    elif total_marks >= 70:
        return 8
    elif total_marks >= 60:
        return 7
    elif total_marks >= 50:
        return 6
    elif total_marks >= 40:
        return 5
    else:
        return 0

def input_subject_data():
    n = int(input("Enter number of subjects: "))
    total_credits = 0
    total_credit_points = 0

    print("\nSubject-wise Entry:")
    for i in range(n):
        print(f"\nSubject {i+1}")
        title = input("  - Subject Title: ")
        code = input("  - Subject Code: ")
        credits = int(input("  - Credits: "))
        internals = int(input("  - Internal Marks: "))
        externals = int(input("  - External Marks: "))
        total = internals + externals
        grade_point = get_grade_point(total)
        credit_point = grade_point * credits

        print(f"    => Total: {total}, Grade Point: {grade_point}, Credit Point: {credit_point}")
        total_credits += credits
        total_credit_points += credit_point

    sgpa = round(total_credit_points / total_credits, 4) if total_credits else 0
    print(f"\n🎓 Final SGPA: {sgpa}")

# Run the script
input_subject_data()
# Out:
# Enter number of subjects: 9
#
# Subject-wise Entry:
#
# Subject 1
#   - Subject Title: TIME
#   - Subject Code: BEC501
#   - Credits: 3
#   - Internal Marks: 50
#   - External Marks: 30
#     => Total: 80, Grade Point: 9, Credit Point: 27
#
# Subject 2
#   - Subject Title: DSP
#   - Subject Code: BEC502
#   - Credits: 4
#   - Internal Marks: 50
#   - External Marks: 34
#     => Total: 84, Grade Point: 9, Credit Point: 36
#
# Subject 3
#   - Subject Title: DC
#   - Subject Code: BEC503
#   - Credits: 4
#   - Internal Marks: 44
#   - External Marks: 29
#     => Total: 73, Grade Point: 8, Credit Point: 32
#
# Subject 4
#   - Subject Title: DSFAT
#   - Subject Code: 515B
#   - Credits: 3
#   - Internal Marks: 48
#   - External Marks: 35
#     => Total: 83, Grade Point: 9, Credit Point: 27
#
# Subject 5
#   - Subject Title: RMIPR
#   - Subject Code: 557
#   - Credits: 3
#   - Internal Marks: 50
#   - External Marks: 36
#     => Total: 86, Grade Point: 9, Credit Point: 27
#
# Subject 6
#   - Subject Title: ES
#   - Subject Code: 508
#   - Credits: 2
#   - Internal Marks: 44
#   - External Marks: 37
#     => Total: 81, Grade Point: 9, Credit Point: 18
#
# Subject 7
#   - Subject Title: COM LAB
#   - Subject Code: 504
#   - Credits: 1
#   - Internal Marks: 50
#   - External Marks: 49
#     => Total: 99, Grade Point: 10, Credit Point: 10
#
# Subject 8
#   - Subject Title: NSS
#   - Subject Code: NIL
#   - Credits: 1
#   - Internal Marks: 0
#   - External Marks: 94
#     => Total: 94, Grade Point: 10, Credit Point: 10
#
# Subject 9
#   - Subject Title: PROJECT
#   - Subject Code: NIL
#   - Credits: 1
#   - Internal Marks: 0
#   - External Marks: 97
#     => Total: 97, Grade Point: 10, Credit Point: 10
#
# 🎓 Final SGPA: 8.9545
